# %% [markdown]
# ## Hypothesis and Analysis of HR Analytics Problem

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('general_data.csv')
data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %% [markdown]
# **1. Employee who travel rarely have more chances for attrition**

# %%
data[data['Attrition']=='Yes'].BusinessTravel.value_counts()
# Out:
# Travel_Rarely        468
# Travel_Frequently    207
# Non-Travel            36
# Name: BusinessTravel, dtype: int64

# %% [markdown]
# **2. Employee who have 13% or low PercentSalaryHike have more chances for attrition**

# %%
temp = data[data['Attrition']=='Yes']

# %%
temp[temp.PercentSalaryHike<=13].PercentSalaryHike.value_counts().sum()
# Out:
# 282

# %% [markdown]
# **3. Employee with low education have low PercentSalaryHike and have more chances for attrition**

# %% [markdown]
# **4. Employee with more years since last promotion have high attrition rate**

# %% [markdown]
# **5. Employees working as HR have higher attrition rate**

# %%
ls = ['Research & Development', 'Sales', 'Human Resources']
for i in range(data.Department.nunique()):
    print(ls[i],"has", temp.Department.value_counts()[i]*100/data.Department.value_counts()[i])
# Out:
# Research & Development has 15.712799167533818
# Sales has 15.022421524663677
# Human Resources has 30.158730158730158

# %% [markdown]
# **6. Employeed with other than Life Sciences, Medical, Marketing, Technical Degree and Human Resources have higher attrition rate.**

# %%
ls = ['Life Sciences', 'Medical', 'Marketing', 'Technical Degree', 'Human Resources', 'Other']
for i in range(data.EducationField.nunique()):
    print(ls[i],"has", temp.EducationField.value_counts()[i]*100/data.EducationField.value_counts()[i])
# Out:
# Life Sciences has 16.666666666666668
# Medical has 16.163793103448278
# Marketing has 15.723270440251572
# Technical Degree has 11.363636363636363
# Human Resources has 13.414634146341463
# Other has 37.03703703703704

# %% [markdown]
# **7. Employees who have worked for more than 4 companies have high attrition rate.**

# %%
for i in range(data.NumCompaniesWorked.nunique()):
    print(i, temp.NumCompaniesWorked.value_counts(sort=False)[i]*100/data.NumCompaniesWorked.value_counts(sort=False)[i])
# Out:
# 0 11.774744027303754
# 1 18.806161745827985
# 2 10.95890410958904
# 3 10.126582278481013
# 4 12.048192771084338
# 5 24.59893048128342
# 6 23.076923076923077
# 7 22.972972972972972
# 8 12.244897959183673
# 9 23.076923076923077

# %% [markdown]
# **8. Employees who have more distance from home have high attrition rate.**

# %% [markdown]
# **9. Employees with less than 3 years of experience have high attrition rate**

# %% [markdown]
# **10. Employees with less than 3 times training since last year have high attrition rate**
